# %%
pip install wolframclient
# Out:
# ...
#   Using cached wolframclient-1.4.0-py2.py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl

session = WolframLanguageSession()
# Out:
# /opt/conda/lib/python3.12/importlib/__init__.py:90: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# WolframKernelException                    Traceback (most recent call last)
# Cell In[2], line 4
#       1 from wolframclient.evaluation import WolframLanguageSession
#       2 from wolframclient.language import wl
# ----> 4 session = WolframLanguageSession()
#
# File /opt/conda/lib/python3.12/site-packages/wolframclient/evaluation/kernel/localsession.py:112, in WolframLanguageSession.__init__(self, kernel, consumer, initfile, kernel_loglevel, stdin, stdout, stderr, inputform_string_evaluation, wxf_bytes_evaluation, controller_class, **kwargs)
# ...

# %%
import shutil
import sympy
print(shutil.which("Wolfram"))
# Out:
# None
