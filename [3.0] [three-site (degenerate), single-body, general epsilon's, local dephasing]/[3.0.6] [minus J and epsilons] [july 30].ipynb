# %%
# retrieving functions from lindbladian.ipnyb
# %run '/home/jovyan/NSERC 2026/[1] [lindbladian helper code] [may 19]/lindbladian.ipynb'
# Out:
# Requirement already satisfied: sympy in /opt/conda/lib/python3.12/site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scienceplots in /opt/conda/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from scienceplots) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->scienceplots) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->scienceplots) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# defining some symbols
J = sp.Symbol("J", real=True, positive=True)
epsilon = sp.Symbol("epsilon", real=True, positive=True)
epsilon1 = sp.Symbol("epsilon1", real=True, positive=True)
epsilon2 = sp.Symbol("epsilon2", real=True, positive=True)
gamma = sp.Symbol("Gamma", real=True, positive=True)
delta = sp.Symbol("delta", real=True, positive=True)

N = 3 # number of sites

# %%
# building lindblad jump operators
L_operators = [sp.Matrix(N,N, lambda i,j: 1 if i==k and j==k else 0) for k in range(N)]

# %% [markdown]
# # $J \mapsto -J$

# %%
# building hamiltonian
H = sp.Matrix([[0, -J, epsilon1], [-J, 0, epsilon2], [epsilon1, epsilon2, 0]])

# building lindbladian
L, rho = lindbladian(output=False, H=H, L_operators=L_operators)

# setting all dephasing constants to the same gamma
L = L.subs({sp.Symbol(f"Gamma_{i}", real=True, nonnegative=True): gamma for i in range(N)})

display(H)
display(L)
# Out:
# ⎡0   -J  ε₁⎤
# ⎢          ⎥
# ⎢-J  0   ε₂⎥
# ⎢          ⎥
# ⎣ε₁  ε₂  0 ⎦
# ⎡  0    -ⅈ⋅J   ⅈ⋅ε₁    ⅈ⋅J     0      0    -ⅈ⋅ε₁    0      0  ⎤
# ⎢                                                             ⎥
# ⎢-ⅈ⋅J    -Γ    ⅈ⋅ε₂     0     ⅈ⋅J     0      0    -ⅈ⋅ε₁    0  ⎥
# ⎢                                                             ⎥
# ⎢ⅈ⋅ε₁   ⅈ⋅ε₂    -Γ      0      0     ⅈ⋅J     0      0    -ⅈ⋅ε₁⎥
# ⎢                                                             ⎥
# ⎢ ⅈ⋅J     0      0     -Γ    -ⅈ⋅J   ⅈ⋅ε₁   -ⅈ⋅ε₂    0      0  ⎥
# ⎢                                                             ⎥
# ⎢  0     ⅈ⋅J     0    -ⅈ⋅J     0    ⅈ⋅ε₂     0    -ⅈ⋅ε₂    0  ⎥
# ⎢                                                             ⎥
# ⎢  0      0     ⅈ⋅J   ⅈ⋅ε₁   ⅈ⋅ε₂    -Γ      0      0    -ⅈ⋅ε₂⎥
# ⎢                                                             ⎥
# ⎢-ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0      0     -Γ    -ⅈ⋅J   ⅈ⋅ε₁ ⎥
# ⎢                                                             ⎥
# ⎢  0    -ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0    -ⅈ⋅J    -Γ    ⅈ⋅ε₂ ⎥
# ⎢                                                             ⎥
# ⎣  0      0    -ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂  ⅈ⋅ε₁   ⅈ⋅ε₂     0  ⎦

# %%
mathematica_code(L).replace("Gamma","Γ").replace("epsilon1", "ϵ").replace("epsilon2", "α")
# Out:
# '{{0, -I*J, I*ϵ, I*J, 0, 0, -I*ϵ, 0, 0}, {-I*J, -Γ, I*α, 0, I*J, 0, 0, -I*ϵ, 0}, {I*ϵ, I*α, -Γ, 0, 0, I*J, 0, 0, -I*ϵ}, {I*J, 0, 0, -Γ, -I*J, I*ϵ, -I*α, 0, 0}, {0, I*J, 0, -I*J, 0, I*α, 0, -I*α, 0}, {0, 0, I*J, I*ϵ, I*α, -Γ, 0, 0, -I*α}, {-I*ϵ, 0, 0, -I*α, 0, 0, -Γ, -I*J, I*ϵ}, {0, -I*ϵ, 0, 0, -I*α, 0, -I*J, -Γ, I*α}, {0, 0, -I*ϵ, 0, 0, -I*α, I*ϵ, I*α, 0}}'

# %% [markdown]
# at this point, I copied the above matrix into a mathematica notebook starting with [3.0.6], computed the eigenvalues and eigenvectors analytically, and then pasted the output into the cells below

# %%
evals_string = '''
{0, -\[CapitalGamma], (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2), 
 ((6*I)*Sqrt[J^4*(-(\[Alpha]^4*\[CapitalGamma]^2) + \[Alpha]^2*(9*J^2 - (6*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)*\[Epsilon]^2 - 
       \[CapitalGamma]^2*\[Epsilon]^4)] - I*J*(6*J^4 - (10*I)*J^3*\[CapitalGamma] - 
     (2*I)*J*\[CapitalGamma]*(-2*\[Alpha]^2 + \[CapitalGamma]^2 - 2*\[Epsilon]^2) + \[CapitalGamma]^2*(\[Alpha]^2 + \[Epsilon]^2) + 
     J^2*(3*\[Alpha]^2 - 2*\[CapitalGamma]^2 + 3*\[Epsilon]^2)))/(2*J^2*(3*J^2 - (2*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)), 
 ((6*I)*Sqrt[J^4*(-(\[Alpha]^4*\[CapitalGamma]^2) + \[Alpha]^2*(9*J^2 - (6*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)*\[Epsilon]^2 - 
       \[CapitalGamma]^2*\[Epsilon]^4)] - I*J*(6*J^4 - (10*I)*J^3*\[CapitalGamma] - 
     (2*I)*J*\[CapitalGamma]*(-2*\[Alpha]^2 + \[CapitalGamma]^2 - 2*\[Epsilon]^2) + \[CapitalGamma]^2*(\[Alpha]^2 + \[Epsilon]^2) + 
     J^2*(3*\[Alpha]^2 - 2*\[CapitalGamma]^2 + 3*\[Epsilon]^2)))/(2*J^2*(3*J^2 - (2*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)), 
 ((6*I)*J^5 - 10*J^4*\[CapitalGamma] + I*J*\[CapitalGamma]^2*(\[Alpha]^2 + \[Epsilon]^2) + 
   I*J^3*(3*\[Alpha]^2 - 2*\[CapitalGamma]^2 + 3*\[Epsilon]^2) + J^2*(4*\[Alpha]^2*\[CapitalGamma] - 2*\[CapitalGamma]^3 + 4*\[CapitalGamma]*\[Epsilon]^2) - 
   (6*I)*Sqrt[J^4*(-(\[Alpha]^4*\[CapitalGamma]^2) + \[Alpha]^2*(9*J^2 + (6*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)*\[Epsilon]^2 - 
       \[CapitalGamma]^2*\[Epsilon]^4)])/(2*J^2*(3*J^2 + (2*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)), 
 ((6*I)*J^5 - 10*J^4*\[CapitalGamma] + I*J*\[CapitalGamma]^2*(\[Alpha]^2 + \[Epsilon]^2) + 
   I*J^3*(3*\[Alpha]^2 - 2*\[CapitalGamma]^2 + 3*\[Epsilon]^2) + J^2*(4*\[Alpha]^2*\[CapitalGamma] - 2*\[CapitalGamma]^3 + 4*\[CapitalGamma]*\[Epsilon]^2) + 
   (6*I)*Sqrt[J^4*(-(\[Alpha]^4*\[CapitalGamma]^2) + \[Alpha]^2*(9*J^2 + (6*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)*\[Epsilon]^2 - 
       \[CapitalGamma]^2*\[Epsilon]^4)])/(2*J^2*(3*J^2 + (2*I)*J*\[CapitalGamma] + \[CapitalGamma]^2)), 
 (J^4*(240*\[CapitalGamma] - 72*Sqrt[-16*J^2 + \[CapitalGamma]^2]) + 4*\[CapitalGamma]^2*(-\[CapitalGamma] + Sqrt[-16*J^2 + \[CapitalGamma]^2])*
    (\[Alpha]^2 + \[Epsilon]^2) + J^2*(-15*\[CapitalGamma]^3 - 36*\[Alpha]^2*Sqrt[-16*J^2 + \[CapitalGamma]^2] + 
     17*\[CapitalGamma]^2*Sqrt[-16*J^2 + \[CapitalGamma]^2] - 36*Sqrt[-16*J^2 + \[CapitalGamma]^2]*\[Epsilon]^2 + 
     84*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2)))/(144*J^4 + 4*\[CapitalGamma]^3*(\[CapitalGamma] - Sqrt[-16*J^2 + \[CapitalGamma]^2]) + 
   J^2*\[CapitalGamma]*(-73*\[CapitalGamma] + 39*Sqrt[-16*J^2 + \[CapitalGamma]^2])), 
 (24*J^4*(10*\[CapitalGamma] + 3*Sqrt[-16*J^2 + \[CapitalGamma]^2]) - 4*\[CapitalGamma]^2*(\[CapitalGamma] + Sqrt[-16*J^2 + \[CapitalGamma]^2])*
    (\[Alpha]^2 + \[Epsilon]^2) + J^2*(-15*\[CapitalGamma]^3 + 36*\[Alpha]^2*Sqrt[-16*J^2 + \[CapitalGamma]^2] - 
     17*\[CapitalGamma]^2*Sqrt[-16*J^2 + \[CapitalGamma]^2] + 36*Sqrt[-16*J^2 + \[CapitalGamma]^2]*\[Epsilon]^2 + 
     84*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2)))/(144*J^4 + 4*\[CapitalGamma]^3*(\[CapitalGamma] + Sqrt[-16*J^2 + \[CapitalGamma]^2]) - 
   J^2*\[CapitalGamma]*(73*\[CapitalGamma] + 39*Sqrt[-16*J^2 + \[CapitalGamma]^2]))}
'''
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/795649818.py:2: SyntaxWarning: invalid escape sequence '\['
#   {0, -\[CapitalGamma], (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2),

# %%
evals_string = '''
(-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
'''

evals_approx = [parse_mathematica(evals_string.replace(r"\[CapitalGamma]", "Gamma").replace(r"\[Epsilon]", "epsilon1").replace(r"\[Alpha]", "epsilon2"))]

evals_approx = [i.subs({sp.Symbol("Gamma"): gamma, sp.Symbol("epsilon1"): epsilon1, sp.Symbol("epsilon2"): epsilon2, sp.Symbol("J"): J}) for i in evals_approx]

for i in evals_approx:
    display(i)


# big gamma limit - second order in eta=1/gamma
evals_big_gamma = []
for i in evals_approx:
    i = i.subs(gamma, 1/sp.Symbol('eta')).series(sp.Symbol('eta'), 0, 3).subs({sp.Symbol('eta'): 1/gamma, epsilon1**2*epsilon2**2: 0}).removeO()
    evals_big_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))


# small gamma limit - second order
evals_small_gamma = []
for i in evals_approx:
    i = i.series(gamma, 0, 3).subs(epsilon1**2*epsilon2**2, 0).removeO()
    evals_small_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/2367855922.py:2: SyntaxWarning: invalid escape sequence '\['
#   (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#       2    2
#      Γ  + J
#    ⎛  2     2⎞
# -3⋅⎝ε₁  + ε₂ ⎠
# ───────────────
#        Γ
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#         2
#        J

# %% [markdown]
# # $\epsilon_1 \mapsto -\epsilon_1$

# %%
# building hamiltonian
H = sp.Matrix([[0, J, -epsilon1], [J, 0, epsilon2], [-epsilon1, epsilon2, 0]])

# building lindbladian
L, rho = lindbladian(output=False, H=H, L_operators=L_operators)

# setting all dephasing constants to the same gamma
L = L.subs({sp.Symbol(f"Gamma_{i}", real=True, nonnegative=True): gamma for i in range(N)})

display(H)
display(L)
# Out:
# ⎡ 0   J   -ε₁⎤
# ⎢            ⎥
# ⎢ J   0   ε₂ ⎥
# ⎢            ⎥
# ⎣-ε₁  ε₂   0 ⎦
# ⎡  0    ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅J     0      0    ⅈ⋅ε₁     0      0  ⎤
# ⎢                                                            ⎥
# ⎢ ⅈ⋅J    -Γ   ⅈ⋅ε₂     0    -ⅈ⋅J     0      0    ⅈ⋅ε₁     0  ⎥
# ⎢                                                            ⎥
# ⎢-ⅈ⋅ε₁  ⅈ⋅ε₂   -Γ      0      0    -ⅈ⋅J     0      0    ⅈ⋅ε₁ ⎥
# ⎢                                                            ⎥
# ⎢-ⅈ⋅J    0      0     -Γ     ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅ε₂    0      0  ⎥
# ⎢                                                            ⎥
# ⎢  0    -ⅈ⋅J    0     ⅈ⋅J     0    ⅈ⋅ε₂     0    -ⅈ⋅ε₂    0  ⎥
# ⎢                                                            ⎥
# ⎢  0     0    -ⅈ⋅J   -ⅈ⋅ε₁  ⅈ⋅ε₂    -Γ      0      0    -ⅈ⋅ε₂⎥
# ⎢                                                            ⎥
# ⎢ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0      0     -Γ     ⅈ⋅J   -ⅈ⋅ε₁⎥
# ⎢                                                            ⎥
# ⎢  0    ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0     ⅈ⋅J    -Γ    ⅈ⋅ε₂ ⎥
# ⎢                                                            ⎥
# ⎣  0     0    ⅈ⋅ε₁     0      0    -ⅈ⋅ε₂  -ⅈ⋅ε₁  ⅈ⋅ε₂     0  ⎦

# %%
mathematica_code(L).replace("Gamma","Γ").replace("epsilon1", "ϵ").replace("epsilon2", "α")
# Out:
# '{{0, I*J, -I*ϵ, -I*J, 0, 0, I*ϵ, 0, 0}, {I*J, -Γ, I*α, 0, -I*J, 0, 0, I*ϵ, 0}, {-I*ϵ, I*α, -Γ, 0, 0, -I*J, 0, 0, I*ϵ}, {-I*J, 0, 0, -Γ, I*J, -I*ϵ, -I*α, 0, 0}, {0, -I*J, 0, I*J, 0, I*α, 0, -I*α, 0}, {0, 0, -I*J, -I*ϵ, I*α, -Γ, 0, 0, -I*α}, {I*ϵ, 0, 0, -I*α, 0, 0, -Γ, I*J, -I*ϵ}, {0, I*ϵ, 0, 0, -I*α, 0, I*J, -Γ, I*α}, {0, 0, I*ϵ, 0, 0, -I*α, -I*ϵ, I*α, 0}}'

# %% [markdown]
# at this point, I copied the above matrix into a mathematica notebook starting with [3.0.6], computed the eigenvalues and eigenvectors analytically, and then pasted the output into the cells below

# %%
evals_string = '''
(-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
'''

evals_approx = [parse_mathematica(evals_string.replace(r"\[CapitalGamma]", "Gamma").replace(r"\[Epsilon]", "epsilon1").replace(r"\[Alpha]", "epsilon2"))]

evals_approx = [i.subs({sp.Symbol("Gamma"): gamma, sp.Symbol("epsilon1"): epsilon1, sp.Symbol("epsilon2"): epsilon2, sp.Symbol("J"): J}) for i in evals_approx]

for i in evals_approx:
    display(i)


# big gamma limit - second order in eta=1/gamma
evals_big_gamma = []
for i in evals_approx:
    i = i.subs(gamma, 1/sp.Symbol('eta')).series(sp.Symbol('eta'), 0, 3).subs({sp.Symbol('eta'): 1/gamma, epsilon1**2*epsilon2**2: 0}).removeO()
    evals_big_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))


# small gamma limit - second order
evals_small_gamma = []
for i in evals_approx:
    i = i.series(gamma, 0, 3).subs(epsilon1**2*epsilon2**2, 0).removeO()
    evals_small_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/2367855922.py:2: SyntaxWarning: invalid escape sequence '\['
#   (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#       2    2
#      Γ  + J
#    ⎛  2     2⎞
# -3⋅⎝ε₁  + ε₂ ⎠
# ───────────────
#        Γ
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#         2
#        J

# %% [markdown]
# # $J \mapsto -J$ and $\epsilon_1 \mapsto -\epsilon_1$

# %%
# building hamiltonian
H = sp.Matrix([[0, -J, -epsilon1], [-J, 0, epsilon2], [-epsilon1, epsilon2, 0]])

# building lindbladian
L, rho = lindbladian(output=False, H=H, L_operators=L_operators)

# setting all dephasing constants to the same gamma
L = L.subs({sp.Symbol(f"Gamma_{i}", real=True, nonnegative=True): gamma for i in range(N)})

display(H)
display(L)
# Out:
# ⎡ 0   -J  -ε₁⎤
# ⎢            ⎥
# ⎢-J   0   ε₂ ⎥
# ⎢            ⎥
# ⎣-ε₁  ε₂   0 ⎦
# ⎡  0    -ⅈ⋅J  -ⅈ⋅ε₁   ⅈ⋅J     0      0    ⅈ⋅ε₁     0      0  ⎤
# ⎢                                                            ⎥
# ⎢-ⅈ⋅J    -Γ   ⅈ⋅ε₂     0     ⅈ⋅J     0      0    ⅈ⋅ε₁     0  ⎥
# ⎢                                                            ⎥
# ⎢-ⅈ⋅ε₁  ⅈ⋅ε₂   -Γ      0      0     ⅈ⋅J     0      0    ⅈ⋅ε₁ ⎥
# ⎢                                                            ⎥
# ⎢ ⅈ⋅J    0      0     -Γ    -ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅ε₂    0      0  ⎥
# ⎢                                                            ⎥
# ⎢  0    ⅈ⋅J     0    -ⅈ⋅J     0    ⅈ⋅ε₂     0    -ⅈ⋅ε₂    0  ⎥
# ⎢                                                            ⎥
# ⎢  0     0     ⅈ⋅J   -ⅈ⋅ε₁  ⅈ⋅ε₂    -Γ      0      0    -ⅈ⋅ε₂⎥
# ⎢                                                            ⎥
# ⎢ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0      0     -Γ    -ⅈ⋅J   -ⅈ⋅ε₁⎥
# ⎢                                                            ⎥
# ⎢  0    ⅈ⋅ε₁    0      0    -ⅈ⋅ε₂    0    -ⅈ⋅J    -Γ    ⅈ⋅ε₂ ⎥
# ⎢                                                            ⎥
# ⎣  0     0    ⅈ⋅ε₁     0      0    -ⅈ⋅ε₂  -ⅈ⋅ε₁  ⅈ⋅ε₂     0  ⎦

# %%
mathematica_code(L).replace("Gamma","Γ").replace("epsilon1", "ϵ").replace("epsilon2", "α")
# Out:
# '{{0, -I*J, -I*ϵ, I*J, 0, 0, I*ϵ, 0, 0}, {-I*J, -Γ, I*α, 0, I*J, 0, 0, I*ϵ, 0}, {-I*ϵ, I*α, -Γ, 0, 0, I*J, 0, 0, I*ϵ}, {I*J, 0, 0, -Γ, -I*J, -I*ϵ, -I*α, 0, 0}, {0, I*J, 0, -I*J, 0, I*α, 0, -I*α, 0}, {0, 0, I*J, -I*ϵ, I*α, -Γ, 0, 0, -I*α}, {I*ϵ, 0, 0, -I*α, 0, 0, -Γ, -I*J, -I*ϵ}, {0, I*ϵ, 0, 0, -I*α, 0, -I*J, -Γ, I*α}, {0, 0, I*ϵ, 0, 0, -I*α, -I*ϵ, I*α, 0}}'

# %% [markdown]
# at this point, I copied the above matrix into a mathematica notebook starting with [3.0.6], computed the eigenvalues and eigenvectors analytically, and then pasted the output into the cells below

# %%
evals_string = '''
(-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
'''

evals_approx = [parse_mathematica(evals_string.replace(r"\[CapitalGamma]", "Gamma").replace(r"\[Epsilon]", "epsilon1").replace(r"\[Alpha]", "epsilon2"))]

evals_approx = [i.subs({sp.Symbol("Gamma"): gamma, sp.Symbol("epsilon1"): epsilon1, sp.Symbol("epsilon2"): epsilon2, sp.Symbol("J"): J}) for i in evals_approx]

for i in evals_approx:
    display(i)


# big gamma limit - second order in eta=1/gamma
evals_big_gamma = []
for i in evals_approx:
    i = i.subs(gamma, 1/sp.Symbol('eta')).series(sp.Symbol('eta'), 0, 3).subs({sp.Symbol('eta'): 1/gamma, epsilon1**2*epsilon2**2: 0}).removeO()
    evals_big_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))


# small gamma limit - second order
evals_small_gamma = []
for i in evals_approx:
    i = i.series(gamma, 0, 3).subs(epsilon1**2*epsilon2**2, 0).removeO()
    evals_small_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/2367855922.py:2: SyntaxWarning: invalid escape sequence '\['
#   (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#       2    2
#      Γ  + J
#    ⎛  2     2⎞
# -3⋅⎝ε₁  + ε₂ ⎠
# ───────────────
#        Γ
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#         2
#        J

# %% [markdown]
# # $J \mapsto -J$ and $\epsilon_1 \mapsto -\epsilon_1$ and $\epsilon_2 \mapsto -\epsilon_2$

# %%
# building hamiltonian
H = sp.Matrix([[0, -J, -epsilon1], [-J, 0, -epsilon2], [-epsilon1, -epsilon2, 0]])

# building lindbladian
L, rho = lindbladian(output=False, H=H, L_operators=L_operators)

# setting all dephasing constants to the same gamma
L = L.subs({sp.Symbol(f"Gamma_{i}", real=True, nonnegative=True): gamma for i in range(N)})

display(H)
display(L)
# Out:
# ⎡ 0   -J   -ε₁⎤
# ⎢             ⎥
# ⎢-J    0   -ε₂⎥
# ⎢             ⎥
# ⎣-ε₁  -ε₂   0 ⎦
# ⎡  0    -ⅈ⋅J   -ⅈ⋅ε₁   ⅈ⋅J     0      0    ⅈ⋅ε₁     0      0  ⎤
# ⎢                                                             ⎥
# ⎢-ⅈ⋅J    -Γ    -ⅈ⋅ε₂    0     ⅈ⋅J     0      0    ⅈ⋅ε₁     0  ⎥
# ⎢                                                             ⎥
# ⎢-ⅈ⋅ε₁  -ⅈ⋅ε₂   -Γ      0      0     ⅈ⋅J     0      0    ⅈ⋅ε₁ ⎥
# ⎢                                                             ⎥
# ⎢ ⅈ⋅J     0      0     -Γ    -ⅈ⋅J   -ⅈ⋅ε₁  ⅈ⋅ε₂     0      0  ⎥
# ⎢                                                             ⎥
# ⎢  0     ⅈ⋅J     0    -ⅈ⋅J     0    -ⅈ⋅ε₂    0    ⅈ⋅ε₂     0  ⎥
# ⎢                                                             ⎥
# ⎢  0      0     ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅ε₂   -Γ      0      0    ⅈ⋅ε₂ ⎥
# ⎢                                                             ⎥
# ⎢ⅈ⋅ε₁     0      0    ⅈ⋅ε₂     0      0     -Γ    -ⅈ⋅J   -ⅈ⋅ε₁⎥
# ⎢                                                             ⎥
# ⎢  0    ⅈ⋅ε₁     0      0    ⅈ⋅ε₂     0    -ⅈ⋅J    -Γ    -ⅈ⋅ε₂⎥
# ⎢                                                             ⎥
# ⎣  0      0    ⅈ⋅ε₁     0      0    ⅈ⋅ε₂   -ⅈ⋅ε₁  -ⅈ⋅ε₂    0  ⎦

# %%
mathematica_code(L).replace("Gamma","Γ").replace("epsilon1", "ϵ").replace("epsilon2", "α")
# Out:
# '{{0, -I*J, -I*ϵ, I*J, 0, 0, I*ϵ, 0, 0}, {-I*J, -Γ, -I*α, 0, I*J, 0, 0, I*ϵ, 0}, {-I*ϵ, -I*α, -Γ, 0, 0, I*J, 0, 0, I*ϵ}, {I*J, 0, 0, -Γ, -I*J, -I*ϵ, I*α, 0, 0}, {0, I*J, 0, -I*J, 0, -I*α, 0, I*α, 0}, {0, 0, I*J, -I*ϵ, -I*α, -Γ, 0, 0, I*α}, {I*ϵ, 0, 0, I*α, 0, 0, -Γ, -I*J, -I*ϵ}, {0, I*ϵ, 0, 0, I*α, 0, -I*J, -Γ, -I*α}, {0, 0, I*ϵ, 0, 0, I*α, -I*ϵ, -I*α, 0}}'

# %% [markdown]
# at this point, I copied the above matrix into a mathematica notebook starting with [3.0.6], computed the eigenvalues and eigenvectors analytically, and then pasted the output into the cells below

# %%
evals_string = '''
(-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
'''

evals_approx = [parse_mathematica(evals_string.replace(r"\[CapitalGamma]", "Gamma").replace(r"\[Epsilon]", "epsilon1").replace(r"\[Alpha]", "epsilon2"))]

evals_approx = [i.subs({sp.Symbol("Gamma"): gamma, sp.Symbol("epsilon1"): epsilon1, sp.Symbol("epsilon2"): epsilon2, sp.Symbol("J"): J}) for i in evals_approx]

for i in evals_approx:
    display(i)


# big gamma limit - second order in eta=1/gamma
evals_big_gamma = []
for i in evals_approx:
    i = i.subs(gamma, 1/sp.Symbol('eta')).series(sp.Symbol('eta'), 0, 3).subs({sp.Symbol('eta'): 1/gamma, epsilon1**2*epsilon2**2: 0}).removeO()
    evals_big_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))


# small gamma limit - second order
evals_small_gamma = []
for i in evals_approx:
    i = i.series(gamma, 0, 3).subs(epsilon1**2*epsilon2**2, 0).removeO()
    evals_small_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/2367855922.py:2: SyntaxWarning: invalid escape sequence '\['
#   (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#       2    2
#      Γ  + J
#    ⎛  2     2⎞
# -3⋅⎝ε₁  + ε₂ ⎠
# ───────────────
#        Γ
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#         2
#        J

# %% [markdown]
# # $\epsilon_1 \mapsto -\epsilon_1$ and $\epsilon_2 \mapsto -\epsilon_2$

# %%
# building hamiltonian
H = sp.Matrix([[0, J, -epsilon1], [J, 0, -epsilon2], [-epsilon1, -epsilon2, 0]])

# building lindbladian
L, rho = lindbladian(output=False, H=H, L_operators=L_operators)

# setting all dephasing constants to the same gamma
L = L.subs({sp.Symbol(f"Gamma_{i}", real=True, nonnegative=True): gamma for i in range(N)})

display(H)
display(L)
# Out:
# ⎡ 0    J   -ε₁⎤
# ⎢             ⎥
# ⎢ J    0   -ε₂⎥
# ⎢             ⎥
# ⎣-ε₁  -ε₂   0 ⎦
# ⎡  0     ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅J     0      0    ⅈ⋅ε₁     0      0  ⎤
# ⎢                                                             ⎥
# ⎢ ⅈ⋅J    -Γ    -ⅈ⋅ε₂    0    -ⅈ⋅J     0      0    ⅈ⋅ε₁     0  ⎥
# ⎢                                                             ⎥
# ⎢-ⅈ⋅ε₁  -ⅈ⋅ε₂   -Γ      0      0    -ⅈ⋅J     0      0    ⅈ⋅ε₁ ⎥
# ⎢                                                             ⎥
# ⎢-ⅈ⋅J     0      0     -Γ     ⅈ⋅J   -ⅈ⋅ε₁  ⅈ⋅ε₂     0      0  ⎥
# ⎢                                                             ⎥
# ⎢  0    -ⅈ⋅J     0     ⅈ⋅J     0    -ⅈ⋅ε₂    0    ⅈ⋅ε₂     0  ⎥
# ⎢                                                             ⎥
# ⎢  0      0    -ⅈ⋅J   -ⅈ⋅ε₁  -ⅈ⋅ε₂   -Γ      0      0    ⅈ⋅ε₂ ⎥
# ⎢                                                             ⎥
# ⎢ⅈ⋅ε₁     0      0    ⅈ⋅ε₂     0      0     -Γ     ⅈ⋅J   -ⅈ⋅ε₁⎥
# ⎢                                                             ⎥
# ⎢  0    ⅈ⋅ε₁     0      0    ⅈ⋅ε₂     0     ⅈ⋅J    -Γ    -ⅈ⋅ε₂⎥
# ⎢                                                             ⎥
# ⎣  0      0    ⅈ⋅ε₁     0      0    ⅈ⋅ε₂   -ⅈ⋅ε₁  -ⅈ⋅ε₂    0  ⎦

# %%
mathematica_code(L).replace("Gamma","Γ").replace("epsilon1", "ϵ").replace("epsilon2", "α")
# Out:
# '{{0, I*J, -I*ϵ, -I*J, 0, 0, I*ϵ, 0, 0}, {I*J, -Γ, -I*α, 0, -I*J, 0, 0, I*ϵ, 0}, {-I*ϵ, -I*α, -Γ, 0, 0, -I*J, 0, 0, I*ϵ}, {-I*J, 0, 0, -Γ, I*J, -I*ϵ, I*α, 0, 0}, {0, -I*J, 0, I*J, 0, -I*α, 0, I*α, 0}, {0, 0, -I*J, -I*ϵ, -I*α, -Γ, 0, 0, I*α}, {I*ϵ, 0, 0, I*α, 0, 0, -Γ, I*J, -I*ϵ}, {0, I*ϵ, 0, 0, I*α, 0, I*J, -Γ, -I*α}, {0, 0, I*ϵ, 0, 0, I*α, -I*ϵ, -I*α, 0}}'

# %% [markdown]
# at this point, I copied the above matrix into a mathematica notebook starting with [3.0.6], computed the eigenvalues and eigenvectors analytically, and then pasted the output into the cells below

# %%
evals_string = '''
(-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
'''

evals_approx = [parse_mathematica(evals_string.replace(r"\[CapitalGamma]", "Gamma").replace(r"\[Epsilon]", "epsilon1").replace(r"\[Alpha]", "epsilon2"))]

evals_approx = [i.subs({sp.Symbol("Gamma"): gamma, sp.Symbol("epsilon1"): epsilon1, sp.Symbol("epsilon2"): epsilon2, sp.Symbol("J"): J}) for i in evals_approx]

for i in evals_approx:
    display(i)


# big gamma limit - second order in eta=1/gamma
evals_big_gamma = []
for i in evals_approx:
    i = i.subs(gamma, 1/sp.Symbol('eta')).series(sp.Symbol('eta'), 0, 3).subs({sp.Symbol('eta'): 1/gamma, epsilon1**2*epsilon2**2: 0}).removeO()
    evals_big_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))


# small gamma limit - second order
evals_small_gamma = []
for i in evals_approx:
    i = i.series(gamma, 0, 3).subs(epsilon1**2*epsilon2**2, 0).removeO()
    evals_small_gamma.append(i)
    display(sp.Add((sp.re(i).factor()),sp.I*(sp.im(i)), evaluate=(True if sp.im(i)==0 else False)))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:2: SyntaxWarning: invalid escape sequence '\['
# /tmp/ipykernel_498/2367855922.py:2: SyntaxWarning: invalid escape sequence '\['
#   (-3*\[CapitalGamma]*(\[Alpha]^2 + \[Epsilon]^2))/(J^2 + \[CapitalGamma]^2)
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#       2    2
#      Γ  + J
#    ⎛  2     2⎞
# -3⋅⎝ε₁  + ε₂ ⎠
# ───────────────
#        Γ
#      ⎛  2     2⎞
# -3⋅Γ⋅⎝ε₁  + ε₂ ⎠
# ─────────────────
#         2
#        J
